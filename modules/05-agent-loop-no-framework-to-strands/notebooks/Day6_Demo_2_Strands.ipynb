# %% [markdown]
# # Day 6 Demo 2 - The same ladder, **with Strands**
#
# Strands writes the agent loop for you. Same six stages as Demo 1: call -> workflow -> agent -> agent+tools -> multi-agent -> multi-agent+tools.
#
# > **Strands calls real Bedrock under the hood - there is no offline mode here.** Run this with AWS credentials and model access (see setup). Compare the line counts with Demo 1.

# %% [markdown]
# ## Before you run (console + setup, in this order)
#
# 1. **Enable model access** - Bedrock console -> **Model catalog** -> **Anthropic Claude Sonnet 4.5** in **us-west-2**.
# 2. **Install** - `pip install strands-agents`.
# 3. **Credentials** - `aws configure` (or env / role). Verify with `aws sts get-caller-identity`.
# 4. **Set the placeholders** - `REGION`, `MODEL` (a `us.` inference profile).

# %%
# %pip install strands-agents
from strands import Agent, tool
from strands.models import BedrockModel

REGION = "us-west-2"
MODEL  = "us.anthropic.claude-sonnet-4-5-20250929-v1:0"   # <-- a us. inference profile you have ENABLED

bedrock = BedrockModel(model_id=MODEL, region_name=REGION, temperature=0.2)
print("Strands model ready:", MODEL)
# Out:
# Strands model ready: us.anthropic.claude-sonnet-4-5-20250929-v1:0

# %% [markdown]
# ## 1 - A single LLM call
#
# An `Agent` with no tools is just an LLM. Call it like a function.

# %%
llm = Agent(model=bedrock)
print(llm("In one sentence, what is an inference profile in Amazon Bedrock?"))
# Out:
# An inference profile in Amazon Bedrock is a configuration that allows you to route requests across multiple AWS regions or models to optimize for availability, latency, and cost while providing a single endpoint for your applications.An inference profile in Amazon Bedrock is a configuration that allows you to route requests across multiple AWS regions or models to optimize for availability, latency, and cost while providing a single endpoint for your applications.

# %% [markdown]
# **Best practices**
# - Set model/temperature on `BedrockModel`, not per call.
# - `print(agent(...))` shows the text; the return value is an `AgentResult` (use `str(result)` or `result.message`).
#
# **Alternatives**
# - Raw `converse` (Demo 1) when you need full control of the request payload or custom retries.

# %% [markdown]
# ## 2 - An LLM workflow (a fixed pipeline)
#
# Two single-purpose agents, called in an order you decide.

# %%
extractor = Agent(model=bedrock,
                  system_prompt='Extract PNR and intent. Reply with ONLY JSON: {"pnr": "...", "intent": "..."}.')
writer    = Agent(model=bedrock,
                  system_prompt="Write a warm 2-sentence customer reply from the given details.")

def workflow(customer_msg):
    data  = extractor(customer_msg)
    reply = writer(str(data))
    return data, reply

ex, reply = workflow("Hi, my flight on PNR JX48Q2 got cancelled. What now?")
print("extracted:", ex)
print("reply    :", reply)
# Out:
# ```json
# {
#   "pnr": "JX48Q2",
#   "intent": "flight_cancellation"
# }
# ```Dear Valued Customer,
#
# Thank you for contacting us regarding your booking with PNR JX48Q2. We understand you'd like to cancel your flight, and we're here to help make this process as smooth as possible for you.
#
# Warm regardsextracted: ```json
# {
#   "pnr": "JX48Q2",
#   "intent": "flight_cancellation"
# }
# ```
#
# reply    : Dear Valued Customer,
#
# Thank you for contacting us regarding your booking with PNR JX48Q2. We understand you'd like to cancel your flight, and we're here to help make this process as smooth as possible for you.
#
# Warm regards

# %% [markdown]
# **Best practices**
# - One agent per step = clear, testable units.
# - Validate structured output between steps (`json.loads`).
#
# **Alternatives**
# - A single agent for trivial chains.
# - `strands.multiagent.GraphBuilder` for a declarative pipeline with branches.

# %% [markdown]
# ## 3 - An *agent* (stateful, multi-turn) - no tools
#
# A Strands `Agent` keeps **conversation memory** across calls. With no tools the loop is a single turn, but the agent now has *state* - the thing a bare call lacks.

# %%
chat = Agent(model=bedrock, system_prompt="You are TravelMind support. Be concise.")
print(chat("My PNR is JX48Q2 and my flight was cancelled."))
print("---")
print(chat("Remind me - what was my PNR?"))   # the agent remembers from the previous turn
# Out:
# I'm sorry to hear your flight was cancelled. Let me help you with PNR **JX48Q2**.
#
# To assist you best, I need to know:
#
# **What would you like to do?**
# 1. **Rebook** on the next available flight
# 2. Request a **full refund**
# 3. Explore **alternative routes**
#
# Also, could you confirm:
# - Your original flight number and date?
# - Are you traveling alone or with others?
#
# I'll get this resolved for you quickly.I'm sorry to hear your flight was cancelled. Let me help you with PNR **JX48Q2**.
#
# To assist you best, I need to know:
#
# **What would you like to do?**
# 1. **Rebook** on the next available flight
# 2. Request a **full refund**
# 3. Explore **alternative routes**
#
# Also, could you confirm:
# - Your original flight number and date?
# - Are you traveling alone or with others?
#
# I'll get this resolved for you quickly.
#
# ---
# Your PNR is **JX48Q2**.
#
# How would you like to proceed with your cancelled flight?Your PNR is **JX48Q2**.
#
# How would you like to proceed with your cancelled flight?

# %% [markdown]
# **Best practices**
# - Conversation history is automatic and grows each call - it costs input tokens; create a new `Agent` to reset.
# - Use a `conversation_manager` to cap/trim history for long sessions.
#
# **Alternatives**
# - Raw `converse` (Demo 1) where you manage the `messages` list yourself.
# - The loop does real work once the agent has **tools** (next).

# %% [markdown]
# ## 4 - An agent **with tool calls**
#
# `@tool` turns a function into a tool: the **docstring** is the description, the **type hints** are the schema. Strands runs the whole tool-use loop you hand-wrote in Demo 1.

# %%
@tool
def lookup_booking(pnr: str) -> dict:
    """Look up a booking by its PNR code."""
    return {"pnr": pnr, "status": "CANCELLED", "flight": "AI-302", "date": "2026-06-12"}

@tool
def get_disruption_reason(pnr: str) -> dict:
    """Why a booking was delayed or cancelled."""
    return {"pnr": pnr, "reason": "weather", "detail": "Heavy fog at origin"}

@tool
def get_rebooking_options(pnr: str) -> list:
    """Alternative flights for a disrupted booking."""
    return [{"flight": "AI-318", "dep": "18:40"}, {"flight": "6E-552", "dep": "21:15"}]

travel_agent = Agent(model=bedrock,
                     tools=[lookup_booking, get_disruption_reason, get_rebooking_options],
                     system_prompt="You are TravelMind, a booking-exception assistant. Never invent a PNR.")

print(travel_agent("My flight on JX48Q2 was disrupted - what happened and what are my options?"))
# Out:
# I'll help you find out what happened to your flight and what rebooking options are available for you.
# Tool #1: get_disruption_reason
#
# Tool #2: get_rebooking_options
# **What happened:**
# Your flight was disrupted due to **heavy fog at the origin airport**. This is a weather-related delay/cancellation.
#
# **Your rebooking options:**
#
# 1. **Flight AI-318** - Departing at 18:40
# 2. **Flight 6E-552** - Departing at 21:15
#
# Both of these alternative flights are available for you to rebook. Would you like help selecting one of these options or need more information about either flight?**What happened:**
# Your flight was disrupted due to **heavy fog at the origin airport**. This is a weather-related delay/cancellation.
#
# **Your rebooking options:**
#
# 1. **Flight AI-318** - Departing at 18:40
# 2. **Flight 6E-552** - Departing at 21:15
#
# Both of these alternative flights are available for you to rebook. Would you like help selecting one of these options or need more information about either flight?

# %% [markdown]
# **Best practices**
# - Write a real docstring and precise type hints - they ARE the tool contract the model reads.
# - Compare with Demo 1 stage 4: no manual `toolUseId`, no append step, no loop - Strands handles all of it.
#
# **Alternatives**
# - The hand-rolled loop (Demo 1) when you need to inspect or customise every turn.
# - A `bedrock-agent-runtime` Knowledge-Base retrieve can be wrapped as a `@tool` too.

# %% [markdown]
# ## 5 - *Multi-agent* - the "agents as tools" pattern
#
# Wrap each specialist `Agent` in a `@tool`, then give those tools to an **orchestrator** agent. The orchestrator decides which specialist to call.

# %%
billing_agent    = Agent(model=bedrock, system_prompt="You are a billing specialist. Be precise about refunds and fees.")
disruption_agent = Agent(model=bedrock, system_prompt="You are a flight-disruption specialist. Be specific and practical.")

@tool
def handle_billing(question: str) -> str:
    """Answer billing, refund, and fee questions."""
    return str(billing_agent(question))

@tool
def handle_disruption(question: str) -> str:
    """Answer flight delay or cancellation questions."""
    return str(disruption_agent(question))

orchestrator = Agent(model=bedrock,
                     tools=[handle_billing, handle_disruption],
                     system_prompt="Route each customer query to the right specialist tool, then return a warm reply under 60 words.")

print(orchestrator("My flight was cancelled and I want to know my options."))
# Out:
# Tool #1: handle_disruption
# # Your Flight Cancellation Options
#
# I'll help you navigate this. Here's what you need to do:
#
# ## **Immediate Actions:**
#
# 1. **Don't leave the airport yet** - You have more leverage in person
# 2. **Check the cancellation reason** - Weather vs. airline operational issues affects your rights
# 3. **Contact the airline NOW** through multiple channels:
#    - Gate agent (fastest if still there)
#    - Airline app
#    - Phone (expect long waits)
#    - Social media (Twitter/X often gets quick responses)
#
# ## **Your Rights & Options:**
#
# ### **Rebooking (Free):**
# - Airlines must rebook you on their next available flight at no charge
# - Ask about flights on **partner airlines** - they can often do this
# - Check if earlier connections exist through different cities
#
# ### **Refund:**
# - You're entitled to a **full refund** if you choose not to travel
# - This applies even to non-refundable tickets when THEY cancel
# - Get it back to original payment method (don't accept vouchers unless they're offering extra value)
#
# ### **Compensation (depends on location):**
# - **EU flights (EU261)**: €250-600 compensation if not weather-related
# - **US flights**: No mandatory compensation, but ask for meal vouchers, hotel, rebooking
# - **Other regions**: Check local regulations
#
# ## **What I need to help you specifically:**
#
# - Which airline?
# - Departure/arrival cities?
# - Reason given for cancellation?
# - Are you at the airport now?
#
# Tell me these details and I'll give you exact next steps.I'm sorry your flight was cancelled! You have options: you can get a **free rebooking** on the next available flight, or request a **full refund** to your original payment method.
# cycle failed
# Traceback (most recent call last):
#   File "/workspace/ - Strands/.venv/lib/python3.14/site-packages/urllib3/response.py", line 905, in _error_catcher
#     yield
#   File "/workspace/ - Strands/.venv/lib/python3.14/site-packages/urllib3/response.py", line 1430, in read_chunked
#     self._update_chunk_length()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/workspace/ - Strands/.venv/lib/python3.14/site-packages/urllib3/response.py", line 1343, in _update_chunk_length
#     line = self._fp.fp.readline()  # type: ignore[union-attr]
#   File "/opt/homebrew/Cellar/python@3.14/3.14.5/Frameworks/Python.framework/Versions/3.14/lib/python3.14/socket.py", line 729, in readinto
#     return self._sock.recv_into(b)
#            ~~~~~~~~~~~~~~~~~~~~^^^
#   File "/opt/homebrew/Cellar/python@3.14/3.14.5/Frameworks/Python.framework/Versions/3.14/lib/python3.14/ssl.py", line 1304, in recv_into
#     return self.read(nbytes, buffer)
#            ~~~~~~~~~^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.14/3.14.5/Frameworks/Python.framework/Versions/3.14/lib/python3.14/ssl.py", line 1138, in read
#     return self._sslobj.read(len, buffer)
#            ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^
# ConnectionResetError: [Errno 54] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/workspace/ - Strands/.venv/lib/python3.14/site-packages/strands/event_loop/event_loop.py", line 294, in event_loop_cycle
#     async for tool_event in tool_events:
#         yield tool_event
#   File "/workspace/ - Strands/.venv/lib/python3.14/site-packages/strands/event_loop/event_loop.py", line 715, in _handle_tool_execution
#     async for event in events:
#         yield event
#   File "/workspace/ - Strands/.venv/lib/python3.14/site-packages/strands/event_loop/event_loop.py", line 382, in recurse_event_loop
#     async for event in events:
#         yield event
#   File "/workspace/ - Strands/.venv/lib/python3.14/site-packages/strands/event_loop/event_loop.py", line 253, in event_loop_cycle
#     async for model_event in model_events:
#         if not isinstance(model_event, ModelStopReason):
#             yield model_event
#   File "/workspace/ - Strands/.venv/lib/python3.14/site-packages/strands/event_loop/event_loop.py", line 533, in _handle_model_execution
#     raise e
#   File "/workspace/ - Strands/.venv/lib/python3.14/site-packages/strands/event_loop/event_loop.py", line 455, in _handle_model_execution
#     async for event in stream_messages(
#     ...<10 lines>...
#         yield event
#   File "/workspace/ - Strands/.venv/lib/python3.14/site-packages/strands/event_loop/streaming.py", line 514, in stream_messages
#     async for event in process_stream(chunks, start_time, cancel_signal):
#         yield event
#   File "/workspace/ - Strands/.venv/lib/python3.14/site-packages/strands/event_loop/streaming.py", line 424, in process_stream
#     async for chunk in chunks:
#     ...<35 lines>...
#             handle_redact_content(chunk["redactContent"], state)
#   File "/workspace/ - Strands/.venv/lib/python3.14/site-packages/strands/models/bedrock.py", line 935, in stream
#     await task
#   File "/opt/homebrew/Cellar/python@3.14/3.14.5/Frameworks/Python.framework/Versions/3.14/lib/python3.14/asyncio/threads.py", line 25, in to_thread
#     return await loop.run_in_executor(None, func_call)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.14/3.14.5/Frameworks/Python.framework/Versions/3.14/lib/python3.14/concurrent/futures/thread.py", line 86, in run
#     result = ctx.run(self.task)
#   File "/opt/homebrew/Cellar/python@3.14/3.14.5/Frameworks/Python.framework/Versions/3.14/lib/python3.14/concurrent/futures/thread.py", line 73, in run
#     return fn(*args, **kwargs)
#   File "/workspace/ - Strands/.venv/lib/python3.14/site-packages/opentelemetry/instrumentation/threading/__init__.py", line 161, in wrapped_func
#     return original_func(*func_args, **func_kwargs)
#   File "/workspace/ - Strands/.venv/lib/python3.14/site-packages/strands/models/bedrock.py", line 972, in _stream
#     for chunk in response["stream"]:
#                  ~~~~~~~~^^^^^^^^^^
#   File "/workspace/ - Strands/.venv/lib/python3.14/site-packages/botocore/eventstream.py", line 591, in __iter__
#     for event in self._event_generator:
#                  ^^^^^^^^^^^^^^^^^^^^^
#   File "/workspace/ - Strands/.venv/lib/python3.14/site-packages/botocore/eventstream.py", line 598, in _create_raw_event_generator
#     for chunk in self._raw_stream.stream():
#                  ~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/workspace/ - Strands/.venv/lib/python3.14/site-packages/urllib3/response.py", line 1260, in stream
#     yield from self.read_chunked(amt, decode_content=decode_content)
#   File "/workspace/ - Strands/.venv/lib/python3.14/site-packages/urllib3/response.py", line 1407, in read_chunked
#     with self._error_catcher():
#          ~~~~~~~~~~~~~~~~~~~^^
#   File "/opt/homebrew/Cellar/python@3.14/3.14.5/Frameworks/Python.framework/Versions/3.14/lib/python3.14/contextlib.py", line 162, in __exit__
#     self.gen.throw(value)
#     ~~~~~~~~~~~~~~^^^^^^^
#   File "/workspace/ - Strands/.venv/lib/python3.14/site-packages/urllib3/response.py", line 928, in _error_catcher
#     raise ProtocolError(f"Connection broken: {e!r}", e) from e
# urllib3.exceptions.ProtocolError: ("Connection broken: ConnectionResetError(54, 'Connection reset by peer')", ConnectionResetError(54, 'Connection reset by peer'))
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File ~/Documents/Agentic AI and AWS GenAI Training/Day-10 - Strands/.venv/lib/python3.14/site-packages/urllib3/response.py:905, in HTTPResponse._error_catcher(self)
#     904 try:
# --> 905     yield
#     907 except SocketTimeout as e:
#     908     # FIXME: Ideally we'd like to include the url in the ReadTimeoutError but
#     909     # there is yet no clean way to get at it from this context.
#
# File ~/Documents/Agentic AI and AWS GenAI Training/Day-10 - Strands/.venv/lib/python3.14/site-packages/urllib3/response.py:1430, in HTTPResponse.read_chunked(self, amt, decode_content)
#    1429 else:
# -> 1430     self._update_chunk_length()
#    1431     self._uncached_read_occurred = True
#
# File ~/Documents/Agentic AI and AWS GenAI Training/Day-10 - Strands/.venv/lib/python3.14/site-packages/urllib3/response.py:1343, in HTTPResponse._update_chunk_length(self)
#    1342     return None
# -> 1343 line = self._fp.fp.readline()  # type: ignore[union-attr]
#    1344 line = line.split(b";", 1)[0]
#
# File /opt/homebrew/Cellar/python@3.14/3.14.5/Frameworks/Python.framework/Versions/3.14/lib/python3.14/socket.py:729, in SocketIO.readinto(self, b)
#     728 try:
# --> 729     return self._sock.recv_into(b)
#     730 except timeout:
#
# File /opt/homebrew/Cellar/python@3.14/3.14.5/Frameworks/Python.framework/Versions/3.14/lib/python3.14/ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#
# File /opt/homebrew/Cellar/python@3.14/3.14.5/Frameworks/Python.framework/Versions/3.14/lib/python3.14/ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1137 if buffer is not None:
# -> 1138     return self._sslobj.read(len, buffer)
#    1139 else:
#
# ConnectionResetError: [Errno 54] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# ProtocolError                             Traceback (most recent call last)
# File ~/Documents/Agentic AI and AWS GenAI Training/Day-10 - Strands/.venv/lib/python3.14/site-packages/strands/event_loop/event_loop.py:294, in event_loop_cycle(agent, invocation_state, structured_output_context, limits)
#     282 tool_events = _handle_tool_execution(
#     283     stop_reason,
#     284     message,
#    (...)    292     limits=limits,
#     293 )
# --> 294 async for tool_event in tool_events:
#     295     yield tool_event
#
# File ~/Documents/Agentic AI and AWS GenAI Training/Day-10 - Strands/.venv/lib/python3.14/site-packages/strands/event_loop/event_loop.py:715, in _handle_tool_execution(stop_reason, message, agent, cycle_trace, cycle_span, cycle_start_time, invocation_state, tracer, structured_output_context, limits)
#     709 events = recurse_event_loop(
#     710     agent=agent,
#     711     invocation_state=invocation_state,
#     712     structured_output_context=structured_output_context,
#     713     limits=limits,
#     714 )
# --> 715 async for event in events:
#     716     yield event
#
# File ~/Documents/Agentic AI and AWS GenAI Training/Day-10 - Strands/.venv/lib/python3.14/site-packages/strands/event_loop/event_loop.py:382, in recurse_event_loop(agent, invocation_state, structured_output_context, limits)
#     376 events = event_loop_cycle(
#     377     agent=agent,
#     378     invocation_state=invocation_state,
#     379     structured_output_context=structured_output_context,
#     380     limits=limits,
#     381 )
# --> 382 async for event in events:
#     383     yield event
#
# File ~/Documents/Agentic AI and AWS GenAI Training/Day-10 - Strands/.venv/lib/python3.14/site-packages/strands/event_loop/event_loop.py:253, in event_loop_cycle(agent, invocation_state, structured_output_context, limits)
#     250 model_events = _handle_model_execution(
#     251     agent, cycle_span, cycle_trace, invocation_state, tracer, structured_output_context
#     252 )
# --> 253 async for model_event in model_events:
#     254     if not isinstance(model_event, ModelStopReason):
#
# File ~/Documents/Agentic AI and AWS GenAI Training/Day-10 - Strands/.venv/lib/python3.14/site-packages/strands/event_loop/event_loop.py:533, in _handle_model_execution(agent, cycle_span, cycle_trace, invocation_state, tracer, structured_output_context)
#     532             yield ForceStopEvent(reason=e)
# --> 533             raise e
#     535 try:
#     536     # Add message in trace and mark the end of the stream messages trace
#
# File ~/Documents/Agentic AI and AWS GenAI Training/Day-10 - Strands/.venv/lib/python3.14/site-packages/strands/event_loop/event_loop.py:455, in _handle_model_execution(agent, cycle_span, cycle_trace, invocation_state, tracer, structured_output_context)
#     453     tool_specs = agent.tool_registry.get_all_tool_specs()
# --> 455 async for event in stream_messages(
#     456     agent.model,
#     457     agent.system_prompt,
#     458     agent.messages,
#     459     tool_specs,
#     460     system_prompt_content=agent._system_prompt_content,
#     461     tool_choice=structured_output_context.tool_choice,
#     462     invocation_state=invocation_state,
#     463     model_state=agent._model_state,
#     464     cancel_signal=agent._cancel_signal,
#     465 ):
#     466     yield event
#
# File ~/Documents/Agentic AI and AWS GenAI Training/Day-10 - Strands/.venv/lib/python3.14/site-packages/strands/event_loop/streaming.py:514, in stream_messages(model, system_prompt, messages, tool_specs, tool_choice, system_prompt_content, invocation_state, model_state, cancel_signal, **kwargs)
#     504 chunks = model.stream(
#     505     messages,
#     506     tool_specs if tool_specs else None,
#    (...)    511     model_state=model_state,
#     512 )
# --> 514 async for event in process_stream(chunks, start_time, cancel_signal):
#     515     yield event
#
# File ~/Documents/Agentic AI and AWS GenAI Training/Day-10 - Strands/.venv/lib/python3.14/site-packages/strands/event_loop/streaming.py:424, in process_stream(chunks, start_time, cancel_signal)
#     422 metrics: Metrics = Metrics(latencyMs=0, timeToFirstByteMs=0)
# --> 424 async for chunk in chunks:
#     425     # Check for cancellation during stream processing
#     426     if cancel_signal and cancel_signal.is_set():
#
# File ~/Documents/Agentic AI and AWS GenAI Training/Day-10 - Strands/.venv/lib/python3.14/site-packages/strands/models/bedrock.py:935, in BedrockModel.stream(self, messages, tool_specs, system_prompt, tool_choice, system_prompt_content, **kwargs)
#     933     yield event
# --> 935 await task
#
# File /opt/homebrew/Cellar/python@3.14/3.14.5/Frameworks/Python.framework/Versions/3.14/lib/python3.14/asyncio/threads.py:25, in to_thread(func, *args, **kwargs)
#      24 func_call = functools.partial(ctx.run, func, *args, **kwargs)
# ---> 25 return await loop.run_in_executor(None, func_call)
#
# File /opt/homebrew/Cellar/python@3.14/3.14.5/Frameworks/Python.framework/Versions/3.14/lib/python3.14/concurrent/futures/thread.py:86, in _WorkItem.run(self, ctx)
#      85 try:
# ---> 86     result = ctx.run(self.task)
#      87 except BaseException as exc:
#
# File /opt/homebrew/Cellar/python@3.14/3.14.5/Frameworks/Python.framework/Versions/3.14/lib/python3.14/concurrent/futures/thread.py:73, in WorkerContext.run(self, task)
#      72 fn, args, kwargs = task
# ---> 73 return fn(*args, **kwargs)
#
# File ~/Documents/Agentic AI and AWS GenAI Training/Day-10 - Strands/.venv/lib/python3.14/site-packages/opentelemetry/instrumentation/threading/__init__.py:161, in ThreadingInstrumentor.__wrap_thread_pool_submit.<locals>.wrapped_func(*func_args, **func_kwargs)
#     160     token = context.attach(otel_context)
# --> 161     return original_func(*func_args, **func_kwargs)
#     162 finally:
#
# File ~/Documents/Agentic AI and AWS GenAI Training/Day-10 - Strands/.venv/lib/python3.14/site-packages/strands/models/bedrock.py:972, in BedrockModel._stream(self, callback, messages, tool_specs, system_prompt_content, tool_choice)
#     971 response = self.client.converse_stream(**request)
# --> 972 for chunk in response["stream"]:
#     973     if (
#     974         "metadata" in chunk
#     975         and "trace" in chunk["metadata"]
#     976         and "guardrail" in chunk["metadata"]["trace"]
#     977     ):
#
# File ~/Documents/Agentic AI and AWS GenAI Training/Day-10 - Strands/.venv/lib/python3.14/site-packages/botocore/eventstream.py:591, in EventStream.__iter__(self)
#     590 def __iter__(self):
# --> 591     for event in self._event_generator:
#     592         parsed_event = self._parse_event(event)
#
# File ~/Documents/Agentic AI and AWS GenAI Training/Day-10 - Strands/.venv/lib/python3.14/site-packages/botocore/eventstream.py:598, in EventStream._create_raw_event_generator(self)
#     597 event_stream_buffer = EventStreamBuffer()
# --> 598 for chunk in self._raw_stream.stream():
#     599     event_stream_buffer.add_data(chunk)
#
# File ~/Documents/Agentic AI and AWS GenAI Training/Day-10 - Strands/.venv/lib/python3.14/site-packages/urllib3/response.py:1260, in HTTPResponse.stream(self, amt, decode_content)
#    1259 if self.chunked and self.supports_chunked_reads():
# -> 1260     yield from self.read_chunked(amt, decode_content=decode_content)
#    1261 else:
#
# File ~/Documents/Agentic AI and AWS GenAI Training/Day-10 - Strands/.venv/lib/python3.14/site-packages/urllib3/response.py:1407, in HTTPResponse.read_chunked(self, amt, decode_content)
#    1402     raise BodyNotHttplibCompatible(
#    1403         "Body should be http.client.HTTPResponse like. "
#    1404         "It should have have an fp attribute which returns raw chunks."
#    1405     )
# -> 1407 with self._error_catcher():
#    1408     # Don't bother reading the body of a HEAD request.
#    1409     if self._original_response and is_response_to_head(self._original_response):
#
# File /opt/homebrew/Cellar/python@3.14/3.14.5/Frameworks/Python.framework/Versions/3.14/lib/python3.14/contextlib.py:162, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     161 try:
# --> 162     self.gen.throw(value)
#     163 except StopIteration as exc:
#     164     # Suppress StopIteration *unless* it's the same exception that
#     165     # was passed to throw().  This prevents a StopIteration
#     166     # raised inside the "with" statement from being suppressed.
#
# File ~/Documents/Agentic AI and AWS GenAI Training/Day-10 - Strands/.venv/lib/python3.14/site-packages/urllib3/response.py:928, in HTTPResponse._error_catcher(self)
#     927 except (HTTPException, OSError) as e:
# --> 928     raise ProtocolError(f"Connection broken: {e!r}", e) from e
#     930 # If no exception is thrown, we should avoid cleaning up
#     931 # unnecessarily.
#
# ProtocolError: ("Connection broken: ConnectionResetError(54, 'Connection reset by peer')", ConnectionResetError(54, 'Connection reset by peer'))
#
# The above exception was the direct cause of the following exception:
#
# EventLoopException                        Traceback (most recent call last)
# Cell In[6], line 18
#      14 orchestrator = Agent(model=bedrock,
#      15                      tools=[handle_billing, handle_disruption],
#      16                      system_prompt="Route each customer query to the right specialist tool, then return a warm reply under 60 words.")
#      17
# ---> 18 print(orchestrator("My flight was cancelled and I want to know my options."))
#
# File ~/Documents/Agentic AI and AWS GenAI Training/Day-10 - Strands/.venv/lib/python3.14/site-packages/strands/agent/agent.py:512, in Agent.__call__(self, prompt, invocation_state, structured_output_model, structured_output_prompt, limits, **kwargs)
#     468 def __call__(
#     469     self,
#     470     prompt: AgentInput = None,
#    (...)    476     **kwargs: Any,
#     477 ) -> AgentResult:
#     478     """Process a natural language prompt through the agent's event loop.
#     479
#     480     This method implements the conversational interface with multiple input patterns:
#    (...)    510             - structured_output: Parsed structured output when structured_output_model was specified
#     511     """
# --> 512     return run_async(
#     513         lambda: self.invoke_async(
#     514             prompt,
#     515             invocation_state=invocation_state,
#     516             structured_output_model=structured_output_model,
#     517             structured_output_prompt=structured_output_prompt,
#     518             limits=limits,
#     519             **kwargs,
#     520         )
#     521     )
#
# File ~/Documents/Agentic AI and AWS GenAI Training/Day-10 - Strands/.venv/lib/python3.14/site-packages/strands/_async.py:34, in run_async(async_func)
#      32 context = contextvars.copy_context()
#      33 future = executor.submit(context.run, execute)
# ---> 34 return future.result()
#
# File /opt/homebrew/Cellar/python@3.14/3.14.5/Frameworks/Python.framework/Versions/3.14/lib/python3.14/concurrent/futures/_base.py:450, in Future.result(self, timeout)
#     448     raise CancelledError()
#     449 elif self._state == FINISHED:
# --> 450     return self.__get_result()
#     451 else:
#     452     raise TimeoutError()
#
# File /opt/homebrew/Cellar/python@3.14/3.14.5/Frameworks/Python.framework/Versions/3.14/lib/python3.14/concurrent/futures/_base.py:395, in Future.__get_result(self)
#     393 if self._exception is not None:
#     394     try:
# --> 395         raise self._exception
#     396     finally:
#     397         # Break a reference cycle with the exception in self._exception
#     398         self = None
#
# File /opt/homebrew/Cellar/python@3.14/3.14.5/Frameworks/Python.framework/Versions/3.14/lib/python3.14/concurrent/futures/thread.py:86, in _WorkItem.run(self, ctx)
#      83     return
#      85 try:
# ---> 86     result = ctx.run(self.task)
#      87 except BaseException as exc:
#      88     self.future.set_exception(exc)
#
# File /opt/homebrew/Cellar/python@3.14/3.14.5/Frameworks/Python.framework/Versions/3.14/lib/python3.14/concurrent/futures/thread.py:73, in WorkerContext.run(self, task)
#      71 def run(self, task):
#      72     fn, args, kwargs = task
# ---> 73     return fn(*args, **kwargs)
#
# File ~/Documents/Agentic AI and AWS GenAI Training/Day-10 - Strands/.venv/lib/python3.14/site-packages/opentelemetry/instrumentation/threading/__init__.py:161, in ThreadingInstrumentor.__wrap_thread_pool_submit.<locals>.wrapped_func(*func_args, **func_kwargs)
#     159 try:
#     160     token = context.attach(otel_context)
# --> 161     return original_func(*func_args, **func_kwargs)
#     162 finally:
#     163     if token is not None:
#
# File ~/Documents/Agentic AI and AWS GenAI Training/Day-10 - Strands/.venv/lib/python3.14/site-packages/strands/_async.py:29, in run_async.<locals>.execute()
#      28 def execute() -> T:
# ---> 29     return asyncio.run(execute_async())
#
# File /opt/homebrew/Cellar/python@3.14/3.14.5/Frameworks/Python.framework/Versions/3.14/lib/python3.14/asyncio/runners.py:204, in run(main, debug, loop_factory)
#     200     raise RuntimeError(
#     201         "asyncio.run() cannot be called from a running event loop")
#     203 with Runner(debug=debug, loop_factory=loop_factory) as runner:
# --> 204     return runner.run(main)
#
# File /opt/homebrew/Cellar/python@3.14/3.14.5/Frameworks/Python.framework/Versions/3.14/lib/python3.14/asyncio/runners.py:127, in Runner.run(self, coro, context)
#     125 self._interrupt_count = 0
#     126 try:
# --> 127     return self._loop.run_until_complete(task)
#     128 except exceptions.CancelledError:
#     129     if self._interrupt_count > 0:
#
# File /opt/homebrew/Cellar/python@3.14/3.14.5/Frameworks/Python.framework/Versions/3.14/lib/python3.14/asyncio/base_events.py:719, in BaseEventLoop.run_until_complete(self, future)
#     716 if not future.done():
#     717     raise RuntimeError('Event loop stopped before Future completed.')
# --> 719 return future.result()
#
# File ~/Documents/Agentic AI and AWS GenAI Training/Day-10 - Strands/.venv/lib/python3.14/site-packages/strands/_async.py:26, in run_async.<locals>.execute_async()
#      25 async def execute_async() -> T:
# ---> 26     return await async_func()
#
# File ~/Documents/Agentic AI and AWS GenAI Training/Day-10 - Strands/.venv/lib/python3.14/site-packages/strands/agent/agent.py:574, in Agent.invoke_async(self, prompt, invocation_state, structured_output_model, structured_output_prompt, limits, **kwargs)
#     533 """Process a natural language prompt through the agent's event loop.
#     534
#     535 This method implements the conversational interface with multiple input patterns:
#    (...)    564         - state: The final state of the event loop
#     565 """
#     566 events = self.stream_async(
#     567     prompt,
#     568     invocation_state=invocation_state,
#    (...)    572     **kwargs,
#     573 )
# --> 574 async for event in events:
#     575     _ = event
#     577 return cast(AgentResult, event["result"])
#
# File ~/Documents/Agentic AI and AWS GenAI Training/Day-10 - Strands/.venv/lib/python3.14/site-packages/strands/agent/agent.py:885, in Agent.stream_async(self, prompt, invocation_state, structured_output_model, structured_output_prompt, limits, **kwargs)
#     880 try:
#     881     events = self._run_loop(
#     882         messages, merged_state, structured_output_model, structured_output_prompt, limits
#     883     )
# --> 885     async for event in events:
#     886         event.prepare(invocation_state=merged_state)
#     888         if event.is_callback_event:
#
# File ~/Documents/Agentic AI and AWS GenAI Training/Day-10 - Strands/.venv/lib/python3.14/site-packages/strands/agent/agent.py:953, in Agent._run_loop(self, messages, invocation_state, structured_output_model, structured_output_prompt, limits)
#     951 # Execute the event loop cycle with retry logic for context limits
#     952 events = self._execute_event_loop_cycle(invocation_state, structured_output_context, limits)
# --> 953 async for event in events:
#     954     # Signal from the model provider that the message sent by the user should be redacted,
#     955     # likely due to a guardrail.
#     956     if (
#     957         isinstance(event, ModelStreamChunkEvent)
#     958         and event.chunk
#     959         and event.chunk.get("redactContent")
#     960         and event.chunk["redactContent"].get("redactUserContentMessage")
#     961     ):
#     962         self.messages[-1]["content"] = self._redact_user_content(
#     963             self.messages[-1]["content"],
#     964             str(event.chunk["redactContent"]["redactUserContentMessage"]),
#     965         )
#
# File ~/Documents/Agentic AI and AWS GenAI Training/Day-10 - Strands/.venv/lib/python3.14/site-packages/strands/agent/agent.py:1024, in Agent._execute_event_loop_cycle(self, invocation_state, structured_output_context, limits)
#    1017 try:
#    1018     events = event_loop_cycle(
#    1019         agent=self,
#    1020         invocation_state=invocation_state,
#    1021         structured_output_context=structured_output_context,
#    1022         limits=limits,
#    1023     )
# -> 1024     async for event in events:
#    1025         yield event
#    1027 except ContextWindowOverflowException as e:
#    1028     # Try reducing the context size and retrying
#
# File ~/Documents/Agentic AI and AWS GenAI Training/Day-10 - Strands/.venv/lib/python3.14/site-packages/strands/event_loop/event_loop.py:341, in event_loop_cycle(agent, invocation_state, structured_output_context, limits)
#     339 yield ForceStopEvent(reason=e)
#     340 logger.exception("cycle failed")
# --> 341 raise EventLoopException(e, invocation_state["request_state"]) from e
#
# EventLoopException: ("Connection broken: ConnectionResetError(54, 'Connection reset by peer')", ConnectionResetError(54, 'Connection reset by peer'))

# %% [markdown]
# **Best practices**
# - The orchestrator's system prompt should state *when* to use each specialist tool.
# - Keep specialists single-domain; the orchestrator owns coordination.
#
# **Alternatives - Swarm (autonomous handoff). Each agent needs a UNIQUE `name`:**
# ```python
# from strands.multiagent import Swarm
# triage = Agent(model=bedrock, name="triage", system_prompt="Route and hand off to a specialist.")
# disr   = Agent(model=bedrock, name="disruption", system_prompt="Flight-disruption specialist.")
# swarm  = Swarm([triage, disr])
# print(swarm("My flight was cancelled, what now?"))
# ```
# Also `strands.multiagent.GraphBuilder` for an explicit DAG of agents.

# %% [markdown]
# ## 6 - Multi-agent **with tool calls**
#
# Now a specialist itself uses tools. The disruption specialist gets the booking tools; the orchestrator coordinates.

# %%
disruption_with_tools = Agent(
    model=bedrock,
    tools=[lookup_booking, get_disruption_reason, get_rebooking_options],
    system_prompt="You are a flight-disruption specialist. Use the tools to look up the booking before answering.")

@tool
def handle_disruption_v2(question: str) -> str:
    """Resolve a flight disruption end to end (looks up the booking, the reason, and the options)."""
    return str(disruption_with_tools(question))

orchestrator2 = Agent(
    model=bedrock,
    tools=[handle_billing, handle_disruption_v2],
    system_prompt="Route each query to the right specialist tool, then return a warm reply under 60 words.")

print(orchestrator2("Flight on JX48Q2 cancelled - what happened and what can I do?"))
# Out:
# Tool #1: handle_disruption_v2
# I'll help you find out why your flight was cancelled and what options are available. Let me look up your booking and get the details.
# Tool #1: lookup_booking
#
# Tool #2: get_disruption_reason
#
# Tool #3: get_rebooking_options
# I have the information about your cancelled flight. Here's what happened:
#
# **Cancellation Reason:**
# Your flight AI-302 on June 12, 2026 was cancelled due to **heavy fog at the origin airport**. This is a weather-related disruption beyond the airline's control.
#
# **Your Rebooking Options:**
# You have two alternative flights available:
#
# 1. **Flight AI-318** - Departing at 18:40
# 2. **Flight 6E-552** - Departing at 21:15
#
# Both options should get you to your destination on the same day. Would you like help selecting one of these flights, or do you need any additional information about these alternatives?I'm sorry your flight was cancelled due to heavy fog! The good news is you have two rebooking options: **Flight AI-318** departing at 18:40 or **Flight 6E-552** at 21:15. Both will get you there today. Which would you prefer, or would you like more details?I'm sorry your flight was cancelled due to heavy fog! The good news is you have two rebooking options: **Flight AI-318** departing at 18:40 or **Flight 6E-552** at 21:15. Both will get you there today. Which would you prefer, or would you like more details?

# %% [markdown]
# **Best practices**
# - A tool-using specialist wrapped as a tool = nested loops; log and bound them.
# - Give each specialist only the tools its domain needs.
#
# **Alternatives**
# - `Swarm` / `GraphBuilder` where each node is itself a tool-using agent.
# - Flatten to one agent with all tools when the coordination overhead is not worth it.

# %% [markdown]
# ## Recap
#
# Same ladder as Demo 1, a fraction of the code. Strands gives you the loop, the tool wiring, and conversation state; you focus on the tools and the roles. Next, **Demo 3** hosts one of these agents on **AgentCore**.
